# %%
from auth.auth import google_auth
from analyzer.gmail_scanner import scan_gmail_for_sensitive_data

if __name__ == "__main__":
    services = google_auth()

    gmail = services["gmail"]
    drive = services["drive"]

    resultados = scan_gmail_for_sensitive_data(gmail, max_messages=50)

    # Mostrar resultados
    for r in resultados:
        print("---- Mensaje ID:", r["message_id"])
        print("Snippet:", r["snippet"])
        print("Datos detectados:", r["detected"])
        print()
# Out:
# ---- Mensaje ID: 19a91b5f2d31a498
# Snippet: Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. guadalupe.quiroga39@gmail.com Ut enim ad minim veniam, quis nostrud
# Datos detectados: {'telefonos': [], 'emails': ['guadalupe.quiroga39@gmail.com', 'belen.verdejo37@outlook.com'], 'cuentas': [], 'dni': ['83886215V', '81747767V'], 'nie': [], 'nombres': ['Enim La', 'Belen Verdejo', 'Guadalupe Quiroga']}
#
# ---- Mensaje ID: 19a91b41901ab491
# Snippet: Lorem ipsum dolor Darío Pinilla Gutiérrez sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim dario.pinilla10@yahoo.com 67513720
# Datos detectados: {'telefonos': [], 'emails': ['dario.pinilla10@yahoo.com'], 'cuentas': [], 'dni': ['68325439Y'], 'nie': [], 'nombres': ['Darío Pinilla', 'Melilla Leocadio', 'Batalla Rojas']}
#
# ---- Mensaje ID: 19a91b24231b85c7
# ...
