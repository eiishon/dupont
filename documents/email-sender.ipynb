# %%
from __future__ import print_function
import os
import base64
import random
import csv
import time
from lorem_text import lorem
from email.mime.text import MIMEText

from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request


SCOPES = ["https://www.googleapis.com/auth/gmail.send"]

def gmail_auth():
    creds = None
    if os.path.exists("token.json"):
        creds = Credentials.from_authorized_user_file("token.json", SCOPES)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file("email-sender-credentials.json", SCOPES)
            creds = flow.run_local_server(port=0)
        with open("token.json", "w") as token:
            token.write(creds.to_json())

    return build("gmail", "v1", credentials=creds)


# leer csv con datos sintéticos 
def cargar_csv(csv_path="muestra.csv"):
    registros = []
    with open(csv_path, newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:
            registros.append(row)
    return registros


# selección aleatoria y campos aleatorios
def elegir_datos_aleatorios(registros):
    # elegir entre 1 y 6 registros
    n_registros = random.randint(1, min(3, len(registros)))
    seleccionados = random.sample(registros, n_registros)

    datos_finales = []

    for reg in seleccionados:
        # elegir entre 1 y 6 columnas aleatorias del registro
        columnas = ["documento", "telefono", "email",
                    "cuenta_bancaria", "nombre", "ciudad"]

        n_campos = random.randint(1, 6)
        campos_aleatorios = random.sample(columnas, n_campos)

        # guardar solo los datos individuales elegidos
        for campo in campos_aleatorios:
            valor = reg[campo]
            datos_finales.append(valor)

    return datos_finales


# insertar datos en texto
def insertar_datos_en_texto(datos):
    texto = lorem.paragraphs(3)
    palabras = texto.split()

    for valor in datos:
        pos = random.randint(0, len(palabras)-1)
        palabras.insert(pos, valor)

    return " ".join(palabras)


# enviar email
def enviar_email(service, destinatario, asunto, mensaje):
    mime_message = MIMEText(mensaje)
    mime_message["to"] = destinatario
    mime_message["subject"] = asunto

    raw = base64.urlsafe_b64encode(mime_message.as_bytes()).decode()
    message = {"raw": raw}

    return service.users().messages().send(userId="me", body=message).execute()


# main
if __name__ == "__main__":
    print("Autenticando con Gmail...")
    service = gmail_auth()

    registros = cargar_csv("muestra.csv")

    total_correos = 50
    retraso_minutos = 2  
    retraso_segundos = retraso_minutos * 60

    for i in range(1, total_correos + 1):
        datos_sueltos = elegir_datos_aleatorios(registros)
        cuerpo = insertar_datos_en_texto(datos_sueltos)
        enviado = enviar_email(
            service,
            destinatario="main.dupont.tfg@gmail.com",
            asunto=f"correo con datos sensibles #{i}",
            mensaje=cuerpo
        )
        print(f"[{i}/{total_correos}] Correo enviado. ID: {enviado['id']}")
        if i < total_correos:
            print(f"Esperando {retraso_minutos} minutos antes del siguiente correo...")
            time.sleep(retraso_segundos)
# Out:
# Autenticando con Gmail...
# [1/50] Correo enviado. ID: 19b9a67d56f3ee79
# Esperando 2 minutos antes del siguiente correo...
# [2/50] Correo enviado. ID: 19b9a69ab6fe1920
# Esperando 2 minutos antes del siguiente correo...
# [3/50] Correo enviado. ID: 19b9a6b81f53d3ea
# Esperando 2 minutos antes del siguiente correo...
# [4/50] Correo enviado. ID: 19b9a6d56e8c6603
# Esperando 2 minutos antes del siguiente correo...
# [5/50] Correo enviado. ID: 19b9a6f2c0e77fbe
# Esperando 2 minutos antes del siguiente correo...
# [6/50] Correo enviado. ID: 19b9a71050133ffe
# Esperando 2 minutos antes del siguiente correo...
# [7/50] Correo enviado. ID: 19b9a72dba4deacf
# Esperando 2 minutos antes del siguiente correo...
# [8/50] Correo enviado. ID: 19b9a74b0f0a9ddd
# Esperando 2 minutos antes del siguiente correo...
# [9/50] Correo enviado. ID: 19b9a7687c45726d
# Esperando 2 minutos antes del siguiente correo...
# [10/50] Correo enviado. ID: 19b9a785e5f657cc
# Esperando 2 minutos antes del siguiente correo...
# [11/50] Correo enviado. ID: 19b9a7a345227020
# Esperando 2 minutos antes del siguiente correo...
# [12/50] Correo enviado. ID: 19b9a7c0a30a65cb
# Esperando 2 minutos antes del siguiente correo...
# [13/50] Correo enviado. ID: 19b9a7de08a1b6c2
# Esperando 2 minutos antes del siguiente correo...
# [14/50] Correo enviado. ID: 19b9a7fb8beca0ff
# Esperando 2 minutos antes del siguiente correo...
# [15/50] Correo enviado. ID: 19b9a8191bb75e7d
# Esperando 2 minutos antes del siguiente correo...
# [16/50] Correo enviado. ID: 19b9a8367263d99a
# Esperando 2 minutos antes del siguiente correo...
# [17/50] Correo enviado. ID: 19b9a8541b76f1fa
# Esperando 2 minutos antes del siguiente correo...
# [18/50] Correo enviado. ID: 19b9a8716bc6d52e
# Esperando 2 minutos antes del siguiente correo...
# [19/50] Correo enviado. ID: 19b9a88ec9657c7b
# Esperando 2 minutos antes del siguiente correo...
# [20/50] Correo enviado. ID: 19b9a8ac4bad55d2
# Esperando 2 minutos antes del siguiente correo...
# [21/50] Correo enviado. ID: 19b9a8c9b551b183
# Esperando 2 minutos antes del siguiente correo...
# [22/50] Correo enviado. ID: 19b9a8e7158f3fbd
# Esperando 2 minutos antes del siguiente correo...
# [23/50] Correo enviado. ID: 19b9a90489c65efc
# Esperando 2 minutos antes del siguiente correo...
# [24/50] Correo enviado. ID: 19b9a921f1ee7854
# Esperando 2 minutos antes del siguiente correo...
# [25/50] Correo enviado. ID: 19b9a93f455df695
# Esperando 2 minutos antes del siguiente correo...
# [26/50] Correo enviado. ID: 19b9a95caaaefad8
# Esperando 2 minutos antes del siguiente correo...
# [27/50] Correo enviado. ID: 19b9a97a2850ab71
# Esperando 2 minutos antes del siguiente correo...
# [28/50] Correo enviado. ID: 19b9a9978eae3baf
# Esperando 2 minutos antes del siguiente correo...
# [29/50] Correo enviado. ID: 19b9a9b4ff66328a
# Esperando 2 minutos antes del siguiente correo...
# [30/50] Correo enviado. ID: 19b9a9d27f5ff13b
# Esperando 2 minutos antes del siguiente correo...
# [31/50] Correo enviado. ID: 19b9a9efc5698d79
# Esperando 2 minutos antes del siguiente correo...
# [32/50] Correo enviado. ID: 19b9aa0d5508383c
# Esperando 2 minutos antes del siguiente correo...
# [33/50] Correo enviado. ID: 19b9aa2aa8160da7
# Esperando 2 minutos antes del siguiente correo...
# [34/50] Correo enviado. ID: 19b9aa480ac8bf14
# Esperando 2 minutos antes del siguiente correo...
# [35/50] Correo enviado. ID: 19b9aa658becccdd
# Esperando 2 minutos antes del siguiente correo...
# [36/50] Correo enviado. ID: 19b9aa82eaed0daa
# Esperando 2 minutos antes del siguiente correo...
# [37/50] Correo enviado. ID: 19b9aaa04db7fa80
# Esperando 2 minutos antes del siguiente correo...
# [38/50] Correo enviado. ID: 19b9aabddf894d95
# Esperando 2 minutos antes del siguiente correo...
# [39/50] Correo enviado. ID: 19b9aadb3d286fa8
# Esperando 2 minutos antes del siguiente correo...
# [40/50] Correo enviado. ID: 19b9aaf882f65aa2
# Esperando 2 minutos antes del siguiente correo...
# [41/50] Correo enviado. ID: 19b9ab16153a6921
# Esperando 2 minutos antes del siguiente correo...
# [42/50] Correo enviado. ID: 19b9ab337e5273b2
# Esperando 2 minutos antes del siguiente correo...
# [43/50] Correo enviado. ID: 19b9ab50c00a06af
# Esperando 2 minutos antes del siguiente correo...
# [44/50] Correo enviado. ID: 19b9ab6e5137b431
# Esperando 2 minutos antes del siguiente correo...
# [45/50] Correo enviado. ID: 19b9ab8ba9d996be
# Esperando 2 minutos antes del siguiente correo...
# [46/50] Correo enviado. ID: 19b9aba938173d54
# Esperando 2 minutos antes del siguiente correo...
# [47/50] Correo enviado. ID: 19b9abc686cfb54a
# Esperando 2 minutos antes del siguiente correo...
# [48/50] Correo enviado. ID: 19b9abe3f7f23fde
# Esperando 2 minutos antes del siguiente correo...
# [49/50] Correo enviado. ID: 19b9ac0198a97721
# Esperando 2 minutos antes del siguiente correo...
# [50/50] Correo enviado. ID: 19b9ac1eec763073
